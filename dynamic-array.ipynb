# %%
# import
import sys
import ctypes

# %%
# To prove python list is dynamic array
test_list = []
print('initial size : ', sys.getsizeof(test_list) )
for e, i in enumerate('Lorem Ipsum is simply dummy text of the printing and typesetting industry',1):
    test_list.append(i)
    print(f'size after {e} update: ', sys.getsizeof(L))
# Out:
# initial size :  56
# size after 1 update:  664
# size after 2 update:  664
# size after 3 update:  664
# size after 4 update:  664
# size after 5 update:  664
# size after 6 update:  664
# size after 7 update:  664
# size after 8 update:  664
# size after 9 update:  664
# size after 10 update:  664
# size after 11 update:  664
# size after 12 update:  664
# size after 13 update:  664
# size after 14 update:  664
# size after 15 update:  664
# size after 16 update:  664
# size after 17 update:  664
# size after 18 update:  664
# size after 19 update:  664
# size after 20 update:  664
# size after 21 update:  664
# size after 22 update:  664
# size after 23 update:  664
# size after 24 update:  664
# size after 25 update:  664
# size after 26 update:  664
# size after 27 update:  664
# size after 28 update:  664
# size after 29 update:  664
# size after 30 update:  664
# size after 31 update:  664
# size after 32 update:  664
# size after 33 update:  664
# size after 34 update:  664
# ...

# %%
class Mypylist:
    def __init__(self):
        self.size = 1
        self.n = 0
        # create a C-type array with size -> self.size
        self.A = self.__make_array(self.size)

    def __len__(self):
        return self.n

    def append(self, item):
        # check if array has empty space
        if self.n == self.size:
            # array is full -> resize
            self.__resize(self.size * 2)

        # adding item
        self.A[self.n] = item
        self.n = self.n + 1

    def pop(self):
        if self.n == 0:
            return "Empty List"
        print(self.A[self.n - 1])
        self.n = self.n - 1

    def clear(self):
        self.n = 0
        self.size = 1

    def find(self, item):
        for i in range(self.n):
            if self.A[i] == item:
                return i
        return "ValueError - not in list"

    def insert(self, pos, item):
        if self.n == self.size:
            self.__resize(self.size * 2)

        for i in range(self.n, pos, -1):
            self.A[i] = self.A[i - 1]

        self.A[pos] = item
        self.n = self.n + 1

    def remove(self, item):
        # search and get pos
        pos = self.find(item)
        if type(pos) == int:
            # delete
            self.__delitem__(pos)
        else:
            return pos

    def __resize(self, new_capacity):
        # create a new array with new capacity
        B = self.__make_array(new_capacity)
        self.size = new_capacity
        # copy the content of old array to new one
        for i in range(self.n):
            B[i] = self.A[i]
        # reassign A
        self.A = B

    def __str__(self):
        result = ""
        for i in range(self.n):
            result = result + str(self.A[i]) + ","

        return "[" + result[:-1] + "]"

    def __getitem__(self, index):
        if 0 <= index < self.n:
            return self.A[index]
        else:
            return "IndexError"

    def __delitem__(self, pos):
        # delete pos wala item
        if 0 <= pos < self.n:
            for i in range(pos, self.n - 1):
                self.A[i] = self.A[i + 1]

            self.n = self.n - 1

    def __make_array(self, capacity):
        # creating C type array(static, referential) with size capacity
        return (capacity * ctypes.py_object)()

# %%
L = Mypylist()

# %%
L.append('poo')
L.append('poo1')
L.append('poo3')
L.append('poo4')
L.append('poo6')

# %%
print(len(L))
L.pop()
print(L)
# Out:
# 5
# poo6
# [poo,poo1,poo3,poo4]
